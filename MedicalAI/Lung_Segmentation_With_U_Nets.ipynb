# %% [markdown]
# # Lung Segmentation
#
# Machine learning can help diagnose disease from medical images such as X-Rays and CT scans. One example of this is diagnosing pneumonia or pneumothorax from chest scans.
#
# Now such tasks might be easier if we know exactly where the lung is in the image! That's where **lung segmentation** comes into play.
#
# In this notebook we'll explore a new application of neural networks called **segmentation**. Segmentation is the task of identifying regions of interest in an image. We'll:
#
#
#
# *   Understand a dataset of *images* and *masks*
# *   Try a relatively simple CNN model, and understand why it fails
# *   Explore a different loss function, Dice, to improve our model
# *   (Optional) Try a special segmentation architecture, U-Nets
#
#
#
#  Let's check it out!

# %%
#@title Run to load data and helper functions
import matplotlib.pyplot as plt
import os
import numpy as np
from pathlib import Path
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, concatenate, MaxPool2D, UpSampling2D
from sklearn.model_selection import train_test_split
import gdown
from ipywidgets import interact, IntSlider

IMG_PATH = "reduced/imgs"
MASK_PATH = "reduced/masks"
EPOCHS = 40

gdown.download("https://drive.google.com/uc?id=1_2UHVdkeuCHwwcb2RGs0cosNw8l_YoAE", "reduced.zip", True)
# !unzip -oq reduced.zip

np.random.seed(12)
tf.random.set_seed(12)

def load():
    imgs_paths = sorted([Path(IMG_PATH) / p for p in os.listdir(IMG_PATH)])
    masks_paths = sorted([Path(MASK_PATH) / p for p in os.listdir(MASK_PATH)])
    imgs = [plt.imread(p) for p in imgs_paths]
    masks = [plt.imread(p)[:, :, 0][:, :, None] > 0.5 for p in masks_paths]
    imgs, masks = np.array(imgs)[:,:,:,0:1], np.array(masks).astype(float)
    imgs_train, imgs_test, masks_train, masks_test = train_test_split(
        imgs, masks, test_size=0.2, shuffle=False
    )
    return imgs_train, imgs_test, masks_train, masks_test

def show_lung_mask_sbs(lung, mask):
    fig, (a1, a2) = plt.subplots(1, 2)
    a1.imshow(lung.squeeze(), cmap = 'gray')
    a2.imshow(mask.squeeze(), cmap = 'gray')
    a1.set_title("lung")
    a2.set_title("mask")


def show_lung_mask_pred_sbs(lung, mask, pred):
    fig, (a1, a2, a3) = plt.subplots(1, 3)
    a1.imshow(lung.squeeze(), cmap = 'gray')
    a2.imshow(mask.squeeze(), cmap = 'gray')
    a3.imshow(pred.squeeze(), cmap = 'gray')
    a1.set_title("lung")
    a2.set_title("mask")
    a3.set_title("predicted mask")

def dice_loss(y_true, y_pred):
    numerator = 2 * tf.reduce_sum(y_true * y_pred, axis=(1, 2, 3))
    denominator = tf.reduce_sum(y_true + y_pred, axis=(1, 2, 3))
    return 1 - numerator / denominator

class ShowLearning(tf.keras.callbacks.Callback):
    def __init__(self, data, masks, name):
        self.data = data
        self.masks = masks
        self.fig_path = f"lung/figs/{name}"
        if not os.path.exists(self.fig_path):
            os.makedirs(self.fig_path)
        super().__init__()

    def on_epoch_begin(self, epoch, logs=None):
        rand_index = np.random.randint(0, len(self.data))
        rand_img = self.data[rand_index][None, :, :, :]
        mask = self.masks[rand_index][None, :, :, :]
        preds = self.model(rand_img).numpy() > 0.5
        show_lung_mask_pred_sbs(rand_img, mask, preds)
        plt.savefig(f"{self.fig_path}/epoch{epoch}.png")
        plt.close()

def show_training_image(name, epoch):
  im = plt.imread(f'lung/figs/{name}/epoch{epoch}.png')
  plt.imshow(im)

def dice_loss(y_true, y_pred):
    numerator = 2 * tf.reduce_sum(y_true * y_pred, axis=(1, 2, 3))
    denominator = tf.reduce_sum(y_true + y_pred, axis=(1, 2, 3))
    return 1 - numerator / denominator

# %% [markdown]
# #Exploring our Data
#
# Let's start by loading in the data and checking out the shapes!
#
# We have lung images as well as their masks, which represent where in the image the lungs are located.

# %%
imgs_train, imgs_test, masks_train, masks_test = load()
print(imgs_train.shape, imgs_test.shape, masks_train.shape, masks_test.shape)
# Out:
# (213, 64, 64, 1) (54, 64, 64, 1) (213, 64, 64, 1) (54, 64, 64, 1)

# %% [markdown]
# **Discuss:** Can you explain the shape of each dataset?

# %% [markdown]
# ## Visualizing our data
#
# This is what the data looks like:

# %%
img_num = 20
show_lung_mask_sbs(imgs_train[img_num], masks_train[img_num])

# %% [markdown]
# **Question**: What are we trying to get our model trying to predict here? What are the inputs and outputs of the model?

# %% [markdown]
# **Exercise:** Use the code above and a for loop to look through the first 5 images.

# %%
#YOUR CODE HERE
for i in range(5):
  show_lung_mask_sbs(imgs_train[i], masks_train[i])

# %% [markdown]
# # Convolutional Neural Networks
#
# We'll start off with a simple convolutional neural network which is typically great for image processing, and see how it does. Note that this is the same as convolutional neural networks we have seen previously but instead of having one output which is the classification, it does a **binary classification on each pixel!**
#
# In particular, for each pixel, the model will have a prediction of whether or not that pixel is part of the lung.
#
# ## Exercise
#
# Add several Conv2D layers to the Sequential Model. To do this just add several calls to
#
# `Conv2D(filters = num_filters, kernel_size = kernel_size, strides = 1, padding='same', activation='relu')`
#
# For the num_filters parameter try any combination of 16 and 32, and for the kernel_size parameter use 3!
#
# We use a stride of `1` and padding of `same` to keep the output's height and width the same after each layer.
#
# **Question:** Why does the final layer have just 1 filter?

# %%
def SimpleConvModel():
    model = tf.keras.models.Sequential(
        [
            #### YOUR CODE HERE to add layers #########
            Conv2D(filters = 16, kernel_size = 3, strides = 1, padding='same', activation='relu'),
            Conv2D(filters = 32, kernel_size = 3, strides = 1, padding='same', activation='relu'),
            Conv2D(filters = 16, kernel_size = 3, strides = 1, padding='same', activation='relu'),
            Conv2D(filters = 32, kernel_size = 3, strides = 1, padding='same', activation='relu'),

            ##### END CODE ########
            Conv2D(filters = 1, kernel_size = 3, strides = 1, padding="same", activation="sigmoid"),
        ]
    ) 
    return model

model = SimpleConvModel()

# %% [markdown]
# Run the next cell to train the model for 40 epochs. While it trains, follow the values of the loss and the accuracy.

# %%
def train(model, imgs, masks, loss, name, epochs):
    optimizer = tf.optimizers.Adam(learning_rate=0.0003)
    model.compile(optimizer=optimizer, loss=loss, metrics=["accuracy"])
    model.fit(imgs, masks, epochs=epochs, callbacks=[ShowLearning(imgs, masks, name)],)

train(model, imgs_train, masks_train, tf.losses.BinaryCrossentropy(), 'simple_conv', EPOCHS)
# Out:
# Epoch 1/40
# 4/7 [================>.............] - ETA: 0s - loss: 0.6935 - accuracy: 0.5694WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0083s vs `on_train_batch_end` time: 0.0116s). Check your callbacks.
# 7/7 [==============================] - 1s 20ms/step - loss: 0.6922 - accuracy: 0.6401
# Epoch 2/40
# 7/7 [==============================] - 0s 17ms/step - loss: 0.6843 - accuracy: 0.7665
# Epoch 3/40
# 7/7 [==============================] - 0s 16ms/step - loss: 0.6700 - accuracy: 0.7662
# Epoch 4/40
# 7/7 [==============================] - 0s 16ms/step - loss: 0.6433 - accuracy: 0.7662
# Epoch 5/40
# 7/7 [==============================] - 0s 16ms/step - loss: 0.6019 - accuracy: 0.7662
# Epoch 6/40
# 7/7 [==============================] - 0s 16ms/step - loss: 0.5608 - accuracy: 0.7662
# Epoch 7/40
# 7/7 [==============================] - 0s 16ms/step - loss: 0.5535 - accuracy: 0.7662
# Epoch 8/40
# 7/7 [==============================] - 0s 16ms/step - loss: 0.5507 - accuracy: 0.7662
# Epoch 9/40
# 7/7 [==============================] - 0s 16ms/step - loss: 0.5453 - accuracy: 0.7662
# Epoch 10/40
# 7/7 [==============================] - 0s 16ms/step - loss: 0.5431 - accuracy: 0.7662
# Epoch 11/40
# 7/7 [==============================] - 0s 16ms/step - loss: 0.5393 - accuracy: 0.7662
# Epoch 12/40
# 7/7 [==============================] - 0s 16ms/step - loss: 0.5360 - accuracy: 0.7662
# Epoch 13/40
# 7/7 [==============================] - 0s 18ms/step - loss: 0.5322 - accuracy: 0.7662
# Epoch 14/40
# 7/7 [==============================] - 0s 16ms/step - loss: 0.5275 - accuracy: 0.7662
# Epoch 15/40
# 7/7 [==============================] - 0s 16ms/step - loss: 0.5215 - accuracy: 0.7662
# Epoch 16/40
# 7/7 [==============================] - 0s 16ms/step - loss: 0.5149 - accuracy: 0.7669
# Epoch 17/40
# 7/7 [==============================] - 0s 16ms/step - loss: 0.5074 - accuracy: 0.7700
# Epoch 18/40
# 7/7 [==============================] - 0s 16ms/step - loss: 0.4990 - accuracy: 0.7749
# Epoch 19/40
# 7/7 [==============================] - 0s 16ms/step - loss: 0.4902 - accuracy: 0.7790
# Epoch 20/40
# 7/7 [==============================] - 1s 15ms/step - loss: 0.4811 - accuracy: 0.7826
# Epoch 21/40
# 7/7 [==============================] - 0s 15ms/step - loss: 0.4713 - accuracy: 0.7875
# Epoch 22/40
# 7/7 [==============================] - 0s 16ms/step - loss: 0.4611 - accuracy: 0.7950
# Epoch 23/40
# 7/7 [==============================] - 0s 16ms/step - loss: 0.4502 - accuracy: 0.8017
# Epoch 24/40
# 7/7 [==============================] - 0s 15ms/step - loss: 0.4391 - accuracy: 0.8085
# Epoch 25/40
# 7/7 [==============================] - 0s 15ms/step - loss: 0.4293 - accuracy: 0.8141
# Epoch 26/40
# 7/7 [==============================] - 0s 16ms/step - loss: 0.4192 - accuracy: 0.8178
# Epoch 27/40
# 7/7 [==============================] - 0s 16ms/step - loss: 0.4133 - accuracy: 0.8212
# Epoch 28/40
# 7/7 [==============================] - 0s 16ms/step - loss: 0.4064 - accuracy: 0.8247
# Epoch 29/40
# 7/7 [==============================] - 0s 16ms/step - loss: 0.4018 - accuracy: 0.8257
# Epoch 30/40
# 7/7 [==============================] - 0s 16ms/step - loss: 0.3982 - accuracy: 0.8291
# Epoch 31/40
# 7/7 [==============================] - 0s 16ms/step - loss: 0.3960 - accuracy: 0.8292
# Epoch 32/40
# 7/7 [==============================] - 0s 16ms/step - loss: 0.3911 - accuracy: 0.8321
# Epoch 33/40
# 7/7 [==============================] - 0s 16ms/step - loss: 0.3859 - accuracy: 0.8338
# Epoch 34/40
# 7/7 [==============================] - 0s 16ms/step - loss: 0.3852 - accuracy: 0.8338
# Epoch 35/40
# 7/7 [==============================] - 0s 16ms/step - loss: 0.3877 - accuracy: 0.8336
# Epoch 36/40
# 7/7 [==============================] - 0s 15ms/step - loss: 0.3791 - accuracy: 0.8369
# Epoch 37/40
# 7/7 [==============================] - 1s 17ms/step - loss: 0.3824 - accuracy: 0.8358
# Epoch 38/40
# 7/7 [==============================] - 0s 17ms/step - loss: 0.3753 - accuracy: 0.8389
# Epoch 39/40
# 7/7 [==============================] - 0s 16ms/step - loss: 0.3703 - accuracy: 0.8397
# Epoch 40/40
# 7/7 [==============================] - 0s 17ms/step - loss: 0.3721 - accuracy: 0.8399

# %% [markdown]
# ### Predicting Model Output Size
# **Discuss: What should the output size of our model be? Why?**
#
# Check your prediction below! We can also visualize the structure of our model.

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_7 (Conv2D)            (None, 64, 64, 16)        160
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 64, 64, 32)        4640
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 64, 64, 16)        4624
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 64, 64, 32)        4640
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 64, 64, 1)         289
# =================================================================
# Total params: 14,353
# Trainable params: 14,353
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Our model probably achieved **> 80% accuracy** - not bad!!
#
# Or is it? Let's take a look at some of the predictions. You'll see that our model got better over time - but how much better?

# %%
interact(lambda epoch: show_training_image('simple_conv', epoch), epoch=(0, EPOCHS-1));
# Out:
# interactive(children=(IntSlider(value=19, description='epoch', max=39), Output()), _dom_classes=('widget-inter…

# %% [markdown]
# **Question:** Why is the accuracy so high when the results look so unimpressive? How exactly is accuracy calculated?

# %% [markdown]
# ## Understanding Model Accuracy
# **Exercise:** In the masks, what is the percentage of pixels that are part of the lung?
#
# *Hint:* The pixels that are part of the lung are represented as `1` in `masks_train`, so you can find the total number of lung pixels with  `masks_train.sum()`.
#
# You might also find `masks_train.size` useful!

# %%
#YOUR CODE HERE to find percent of pixels in masks that are part of the lung
lung_pixels = masks_train.sum()
total_pixels = masks_train.size
print(lung_pixels/total_pixels)
# Out:
# 0.23375605193661972

# %% [markdown]
# **Question:** What accuracy could we get if we just predicted all the pixels were not part of the lung?
#
# **Question:** Why is accuracy not super useful for this segmentation task?

# %% [markdown]
# Well, it seems like the model is outputing 'not lung' for most pixels. And because in our images most of the pixels are not part of the lung, the model can get pretty high accuracy by just guessing 'not lung' for each pixel! This is clearly not what we want.
#
# We can try something to address this. First of all, we'll need to rethink what it means to have a 'good' prediction, as just accuracy is clearly not adequate! We need some way to measure how much overlap there is between the *real* lung masks and our predictions.

# %% [markdown]
# #Exploring the Loss Function
#
# ##The Dice Coefficient
#
# Instead of accuracy, we'll use a common metric known as the Dice Coefficient (or Sørensen–Dice if you're feeling fancy), which is calculated as follows:
#
# $$\frac{2*|T \cap P|}{|T| + |P|}$$
#
# ![test](https://miro.medium.com/max/429/1*yUd5ckecHjWZf6hGrdlwzA.png)
#
# **$T$**, in blue, is the set of pixels in the image that are **truly part of the lung.**
#
# **$P$**, in red, is the set of pixels that are **predicted to be part of the lung**.
#
# The numerator is the **overlap of true and predicted**: how many pixels are in both categories?
#
# The denominator is the **sum** of **the number of pixels truly in the lung**, plus **the number of pixels that are predicted to be part of the lung**.
#
# Some intuition: to get a high (good) Dice Coefficient, we need a **large numerator** and a **small denominator**.
# * To make the numerator large, there needs to be a lot of overlap between the true and predicted 'lung' pixels.
# * To make the denominator small, there shouldn't be that many pixels that are predicted as 'lung' - otherwise we could "cheat" by predicting everything is part of the lung!
#
# **Question:** What would the Dice Coefficient be if we make a perfect prediction? Why is there a 2 in the numerator?
#
# **Question:** What would the Dice Coefficient be if we predict all 'not lung'?
#
# **Question**: What's another way we could get a Dice Coefficient of 0?

# %% [markdown]
# ## (Optional, Advanced): Implementing Dice
# **Exercise:** Implement a function that returns the Dice coefficient.
#
# Hint:  `sum(true_mask & predicted_mask`) counts the number of pixels that are in both the true mask and the predicted mask.

# %%
def dice(true_mask, predicted_mask):
    #flatten the data
    true_mask, predicted_mask = true_mask.astype(bool).flatten(), predicted_mask.astype(bool).flatten()
    return (2*sum(true_mask & predicted_mask)/(sum(true_mask)+sum(predicted_mask)))
    #YOUR CODE HERE to return the dice coefficient

# %% [markdown]
# Now, let's try out our Dice score - how well do our predictions do? By changing the inputs, can you achieve a Dice score of 0.0 or 1.0?

# %%
img_num = 43 #Choose any image

img = np.expand_dims(imgs_train[img_num],0)
true_mask = masks_train[img_num]
pred_mask = model.predict(img) > 0.5

show_lung_mask_pred_sbs(img, true_mask, pred_mask)

print("Dice score:", dice(true_mask, pred_mask)) #Try changing the inputs to dice!
# Out:
# Dice score: 0.4671953857245854

# %%
#YOUR CODE HERE to explore changing the inputs (create some arrays!)
for i in range(10):
  img_num = i*5 #Choose any image

  img = np.expand_dims(imgs_train[img_num],0)
  true_mask = masks_train[img_num]
  pred_mask = model.predict(img) > 0.5

  show_lung_mask_pred_sbs(img, true_mask, pred_mask)

  print("Dice score:", dice(true_mask, pred_mask))
# Out:
# Dice score: 0.6847888953152111
# Dice score: 0.54733492442323
# Dice score: 0.4953560371517028
# Dice score: 0.585464333781965
# Dice score: 0.5377094972067039
# Dice score: 0.7258064516129032
# Dice score: 0.46906636670416196
# Dice score: 0.5201520912547528
# Dice score: 0.6726001271455817
# Dice score: 0.6093052899936265

# %% [markdown]
# ## Same model, different loss
#
# To make our model actually *find* the lungs rather than using the "always guess no" trick, we can try changing the loss function. Remember that the **the model tries to minimize the loss function during training**. Now that we care about the Dice Coefficient more than accuracy, we can change our loss function to reflect that.
#
# Note that "Dice Loss" is just 1 - Dice: minimizing Dice Loss is the same thing as maximizing the Dice Coefficient!

# %%
model_with_dice = SimpleConvModel()
train(model_with_dice, imgs_train, masks_train, dice_loss, 'simple_conv_with_dice', EPOCHS)
# Out:
# Epoch 1/40
# 4/7 [================>.............] - ETA: 0s - loss: 0.6864 - accuracy: 0.5147WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0081s vs `on_train_batch_end` time: 0.0112s). Check your callbacks.
# 7/7 [==============================] - 1s 19ms/step - loss: 0.6865 - accuracy: 0.4382
# Epoch 2/40
# 7/7 [==============================] - 0s 18ms/step - loss: 0.6851 - accuracy: 0.2783
# Epoch 3/40
# 7/7 [==============================] - 0s 18ms/step - loss: 0.6835 - accuracy: 0.2668
# Epoch 4/40
# 7/7 [==============================] - 0s 16ms/step - loss: 0.6809 - accuracy: 0.2719
# Epoch 5/40
# 7/7 [==============================] - 0s 16ms/step - loss: 0.6764 - accuracy: 0.2718
# Epoch 6/40
# 7/7 [==============================] - 0s 16ms/step - loss: 0.6683 - accuracy: 0.2635
# Epoch 7/40
# 7/7 [==============================] - 0s 16ms/step - loss: 0.6549 - accuracy: 0.2535
# Epoch 8/40
# 7/7 [==============================] - 0s 16ms/step - loss: 0.6356 - accuracy: 0.2544
# Epoch 9/40
# 7/7 [==============================] - 0s 15ms/step - loss: 0.6153 - accuracy: 0.2874
# Epoch 10/40
# 7/7 [==============================] - 0s 16ms/step - loss: 0.5944 - accuracy: 0.3761
# Epoch 11/40
# 7/7 [==============================] - 0s 15ms/step - loss: 0.5799 - accuracy: 0.4332
# Epoch 12/40
# 7/7 [==============================] - 0s 16ms/step - loss: 0.5702 - accuracy: 0.4464
# Epoch 13/40
# 7/7 [==============================] - 0s 16ms/step - loss: 0.5640 - accuracy: 0.4653
# Epoch 14/40
# 7/7 [==============================] - 0s 15ms/step - loss: 0.5591 - accuracy: 0.4713
# Epoch 15/40
# 7/7 [==============================] - 0s 16ms/step - loss: 0.5543 - accuracy: 0.4854
# Epoch 16/40
# 7/7 [==============================] - 0s 17ms/step - loss: 0.5493 - accuracy: 0.4971
# Epoch 17/40
# 7/7 [==============================] - 0s 16ms/step - loss: 0.5429 - accuracy: 0.5159
# Epoch 18/40
# 7/7 [==============================] - 0s 16ms/step - loss: 0.5347 - accuracy: 0.5357
# Epoch 19/40
# 7/7 [==============================] - 0s 16ms/step - loss: 0.5237 - accuracy: 0.5764
# Epoch 20/40
# 7/7 [==============================] - 0s 15ms/step - loss: 0.5101 - accuracy: 0.6274
# Epoch 21/40
# 7/7 [==============================] - 0s 15ms/step - loss: 0.4969 - accuracy: 0.6608
# Epoch 22/40
# 7/7 [==============================] - 0s 16ms/step - loss: 0.4801 - accuracy: 0.7445
# Epoch 23/40
# 7/7 [==============================] - 0s 15ms/step - loss: 0.4654 - accuracy: 0.8112
# Epoch 24/40
# 7/7 [==============================] - 0s 16ms/step - loss: 0.4539 - accuracy: 0.7984
# Epoch 25/40
# 7/7 [==============================] - 0s 15ms/step - loss: 0.4411 - accuracy: 0.8200
# Epoch 26/40
# 7/7 [==============================] - 0s 17ms/step - loss: 0.4318 - accuracy: 0.8248
# Epoch 27/40
# 7/7 [==============================] - 0s 16ms/step - loss: 0.4226 - accuracy: 0.8248
# Epoch 28/40
# 7/7 [==============================] - 0s 16ms/step - loss: 0.4153 - accuracy: 0.8063
# Epoch 29/40
# 7/7 [==============================] - 0s 15ms/step - loss: 0.4125 - accuracy: 0.8179
# Epoch 30/40
# 7/7 [==============================] - 0s 15ms/step - loss: 0.4056 - accuracy: 0.8302
# Epoch 31/40
# 7/7 [==============================] - 0s 16ms/step - loss: 0.3997 - accuracy: 0.8327
# Epoch 32/40
# 7/7 [==============================] - 0s 16ms/step - loss: 0.3959 - accuracy: 0.8265
# Epoch 33/40
# 7/7 [==============================] - 0s 16ms/step - loss: 0.3909 - accuracy: 0.8334
# Epoch 34/40
# 7/7 [==============================] - 0s 16ms/step - loss: 0.3920 - accuracy: 0.8104
# Epoch 35/40
# 7/7 [==============================] - 0s 16ms/step - loss: 0.3950 - accuracy: 0.8336
# Epoch 36/40
# 7/7 [==============================] - 0s 16ms/step - loss: 0.3844 - accuracy: 0.8338
# Epoch 37/40
# 7/7 [==============================] - 0s 17ms/step - loss: 0.3822 - accuracy: 0.8381
# Epoch 38/40
# 7/7 [==============================] - 0s 16ms/step - loss: 0.3812 - accuracy: 0.8346
# Epoch 39/40
# 7/7 [==============================] - 0s 15ms/step - loss: 0.3771 - accuracy: 0.8346
# Epoch 40/40
# 7/7 [==============================] - 0s 16ms/step - loss: 0.3947 - accuracy: 0.8266

# %%
interact(lambda epoch: show_training_image('simple_conv_with_dice', epoch), epoch=(0, EPOCHS-1));
# Out:
# interactive(children=(IntSlider(value=19, description='epoch', max=39), Output()), _dom_classes=('widget-inter…

# %% [markdown]
# **Question**: Compare the above results to the results from before. Are the predictions any better or more believable than before? What is a new problem that is arising?

# %% [markdown]
# # (Optional) Changing Our Model: U-Nets
#
# So even though we have changed our loss to better suit the problem, we can still do better! To do this, we'll use U-Nets, which are a special type of convolutional neural network with a "U shaped" architecture. It works by first compressing and then expanding the image back to full size.
#
# Compressing the image (on the left side of the U) allows us to create many feature maps. Then - since for segmentation we need to output an image of the same size as the original - we upsample. Importantly, we also copy the original feature maps of a particular size during the compression stage. This greatly reduces distortion, as it is like we have a copy of the original image in the expansion section.
#
# U-Nets are tricky to understand - no worries if you're fuzzy on some of the details!
# ![alt text](https://miro.medium.com/max/2824/1*f7YOaE4TWubwaFF7Z1fzNw.png)

# %% [markdown]
# We've implemented a small U-Net for you here (**not exactly the diagram**). Check it out and experiment with it if you're interested! You'll notice it has only five "sections" total (two on the way down, one at the bottom, and two on the way up). What does each section consist of?
#
# **Try drawing a diagram for this U-Net!**

# %%
#Check out the U-Net code if you're interested!

def section(conv1_filters, conv2_filters): #Represents one horizontal "section" of the U
    return tf.keras.Sequential(
        [
            Conv2D(conv1_filters, 3, padding="same", activation="relu"),
            Conv2D(conv2_filters, 3, padding="same", activation="relu"),
        ]
    )

class U_Net(tf.keras.Model):
    def __init__(self):
        super(U_Net, self).__init__() #What do the numbers represent? 
        self.section1 = section(16, 16)
        self.section2 = section(32, 32)
        self.section3 = section(32, 64) #Bottom of the U!
        self.section4 = section(32, 32)
        self.section5 = section(16, 16)
        self.final_conv = Conv2D(1, 3, padding="same", activation="sigmoid")
        self.maxpool1, self.maxpool2 = MaxPool2D(2), MaxPool2D(2) #Why are there two of these?
        self.upsample1, self.upsample2 = UpSampling2D(2), UpSampling2D(2)

    def call(self, inputs):
        input1 = self.section1(inputs)
        input2 = self.section2(self.maxpool1(input1))
        input3 = self.section3(self.maxpool2(input2))
        input4 = self.section4(concatenate([input2, self.upsample1(input3)]))
        input5 = self.section5(concatenate([input1, self.upsample2(input4)]))
        output = self.final_conv(input5)
        return output

# %%
unet = U_Net()

# %% [markdown]
# Let's use Dice Loss with our U-Net.
#
# As this model trains, look at how the accuracy and loss change. Is the training generally steady or are there certain epochs with breakthroughs?

# %%
train(unet, imgs_train, masks_train, dice_loss, 'unet_with_dice', epochs=80)
# Out:
# Epoch 1/80
# 7/7 [==============================] - 1s 27ms/step - loss: 0.3100 - accuracy: 0.8407
# Epoch 2/80
# 7/7 [==============================] - 0s 23ms/step - loss: 0.1690 - accuracy: 0.9232
# Epoch 3/80
# 7/7 [==============================] - 0s 19ms/step - loss: 0.1264 - accuracy: 0.9457
# Epoch 4/80
# 7/7 [==============================] - 0s 17ms/step - loss: 0.1144 - accuracy: 0.9493
# Epoch 5/80
# 7/7 [==============================] - 0s 17ms/step - loss: 0.1038 - accuracy: 0.9558
# Epoch 6/80
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0979 - accuracy: 0.9573
# Epoch 7/80
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0930 - accuracy: 0.9598
# Epoch 8/80
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0906 - accuracy: 0.9610
# Epoch 9/80
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0877 - accuracy: 0.9621
# Epoch 10/80
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0864 - accuracy: 0.9631
# Epoch 11/80
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0852 - accuracy: 0.9636
# Epoch 12/80
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0839 - accuracy: 0.9640
# Epoch 13/80
# 7/7 [==============================] - 1s 17ms/step - loss: 0.0828 - accuracy: 0.9645
# Epoch 14/80
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0821 - accuracy: 0.9650
# Epoch 15/80
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0814 - accuracy: 0.9652
# Epoch 16/80
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0807 - accuracy: 0.9655
# Epoch 17/80
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0797 - accuracy: 0.9659
# Epoch 18/80
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0790 - accuracy: 0.9663
# Epoch 19/80
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0786 - accuracy: 0.9664
# Epoch 20/80
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0782 - accuracy: 0.9666
# Epoch 21/80
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0777 - accuracy: 0.9667
# Epoch 22/80
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0767 - accuracy: 0.9673
# Epoch 23/80
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0776 - accuracy: 0.9668
# Epoch 24/80
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0776 - accuracy: 0.9668
# Epoch 25/80
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0760 - accuracy: 0.9677
# Epoch 26/80
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0764 - accuracy: 0.9673
# Epoch 27/80
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0742 - accuracy: 0.9683
# Epoch 28/80
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0735 - accuracy: 0.9686
# Epoch 29/80
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0727 - accuracy: 0.9690
# Epoch 30/80
# 7/7 [==============================] - 1s 17ms/step - loss: 0.0730 - accuracy: 0.9688
# Epoch 31/80
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0739 - accuracy: 0.9685
# Epoch 32/80
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0713 - accuracy: 0.9697
# Epoch 33/80
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0706 - accuracy: 0.9700
# Epoch 34/80
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0700 - accuracy: 0.9702
# Epoch 35/80
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0704 - accuracy: 0.9700
# Epoch 36/80
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0694 - accuracy: 0.9705
# Epoch 37/80
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0686 - accuracy: 0.9707
# Epoch 38/80
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0680 - accuracy: 0.9710
# Epoch 39/80
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0675 - accuracy: 0.9712
# Epoch 40/80
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0668 - accuracy: 0.9715
# Epoch 41/80
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0671 - accuracy: 0.9714
# Epoch 42/80
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0680 - accuracy: 0.9707
# Epoch 43/80
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0670 - accuracy: 0.9714
# Epoch 44/80
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0687 - accuracy: 0.9706
# Epoch 45/80
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0679 - accuracy: 0.9706
# Epoch 46/80
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0652 - accuracy: 0.9722
# Epoch 47/80
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0646 - accuracy: 0.9724
# Epoch 48/80
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0639 - accuracy: 0.9728
# Epoch 49/80
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0641 - accuracy: 0.9727
# Epoch 50/80
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0631 - accuracy: 0.9731
# Epoch 51/80
# 7/7 [==============================] - 1s 17ms/step - loss: 0.0620 - accuracy: 0.9734
# Epoch 52/80
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0615 - accuracy: 0.9738
# Epoch 53/80
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0611 - accuracy: 0.9740
# Epoch 54/80
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0617 - accuracy: 0.9737
# Epoch 55/80
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0601 - accuracy: 0.9743
# Epoch 56/80
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0599 - accuracy: 0.9743
# Epoch 57/80
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0610 - accuracy: 0.9740
# Epoch 58/80
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0607 - accuracy: 0.9739
# Epoch 59/80
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0622 - accuracy: 0.9732
# Epoch 60/80
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0599 - accuracy: 0.9743
# Epoch 61/80
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0604 - accuracy: 0.9742
# Epoch 62/80
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0590 - accuracy: 0.9748
# Epoch 63/80
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0578 - accuracy: 0.9753
# Epoch 64/80
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0575 - accuracy: 0.9753
# Epoch 65/80
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0570 - accuracy: 0.9755
# Epoch 66/80
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0572 - accuracy: 0.9754
# Epoch 67/80
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0569 - accuracy: 0.9754
# Epoch 68/80
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0559 - accuracy: 0.9760
# Epoch 69/80
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0562 - accuracy: 0.9758
# Epoch 70/80
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0562 - accuracy: 0.9758
# Epoch 71/80
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0572 - accuracy: 0.9753
# Epoch 72/80
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0555 - accuracy: 0.9761
# Epoch 73/80
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0561 - accuracy: 0.9758
# Epoch 74/80
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0553 - accuracy: 0.9762
# Epoch 75/80
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0544 - accuracy: 0.9767
# Epoch 76/80
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0542 - accuracy: 0.9766
# Epoch 77/80
# 7/7 [==============================] - 1s 16ms/step - loss: 0.0545 - accuracy: 0.9765
# Epoch 78/80
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0551 - accuracy: 0.9762
# Epoch 79/80
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0540 - accuracy: 0.9767
# Epoch 80/80
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0543 - accuracy: 0.9766

# %%
interact(lambda epoch: show_training_image('unet_with_dice', epoch), epoch=(0, EPOCHS-1));
# Out:
# interactive(children=(IntSlider(value=19, description='epoch', max=39), Output()), _dom_classes=('widget-inter…

# %% [markdown]
# ## Evaluation

# %% [markdown]
# Run the next cell to visualize the predictions of the UNet on the test set! As a reminder, our model has never seen this data before. Will it be able to predict somewhat accurate looking masks?

# %%
thresh = 0.5 #Experiment with changing this!
preds = unet(imgs_test).numpy()
preds = preds >= thresh

def show_preds_helper(imgs_test, masks_test, preds, ind):
    show_lung_mask_pred_sbs(imgs_test[ind], masks_test[ind], preds[ind])
    plt.show()

interact(lambda i: show_preds_helper(imgs_test, masks_test, preds, i), i=(0, len(preds)-1));
# Out:
# interactive(children=(IntSlider(value=26, description='i', max=53), Output()), _dom_classes=('widget-interact'…

# %% [markdown]
# Pretty darn good :)

# %% [markdown]
# ## Advanced: Improving Your Model
#
# Keep experimenting with our models to see if you can achieve human-level performance! You can try a few things:
#
#
# *   Train for more epochs.
# *   Try changing the hyperparameters, like learning rate.
# *   Experiment with the structure of U-Net: can you change the number of sections, or the sizes of the convolutions within each section?
# *   Change the threshold for our prediction. For example, if we see that we're overpredicting lung pixels, we could set our threshold a little higher. Remember that the raw output of our models is a probability value for each pixel on whether or not it is part of the lung!
# *   *Advanced Challenge*: try implementing a different loss function, like the [Jaccard index](https://en.wikipedia.org/wiki/Jaccard_index) or [pixel-wise cross-entropy loss](https://www.jeremyjordan.me/semantic-segmentation/) (which is the loss function we used in our first model). Check out the `dice_loss` function in the hidden cell at the top for an example of the function's structure.
#
# Work with your group to see if you can create a perfect model!

# %%
#YOUR CODE HERE for further experimentation
def jaccard_loss(y_true, y_pred):
    numerator = tf.reduce_sum(y_true * y_pred, axis=(1, 2, 3))
    denominator = tf.reduce_sum(y_true + y_pred, axis=(1, 2, 3))-tf.reduce_sum(y_true * y_pred, axis=(1, 2, 3))
    return 1 - numerator / denominator
train(unet, imgs_train, masks_train, dice_loss, 'unet_with_dice', epochs=100)
# Out:
# Epoch 1/100
# 5/7 [====================>.........] - ETA: 0s - loss: 0.1003 - accuracy: 0.9555WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0141s vs `on_train_batch_end` time: 0.0153s). Check your callbacks.
# 7/7 [==============================] - 1s 29ms/step - loss: 0.0947 - accuracy: 0.9577
# Epoch 2/100
# 7/7 [==============================] - 0s 21ms/step - loss: 0.0649 - accuracy: 0.9722
# Epoch 3/100
# 7/7 [==============================] - 0s 19ms/step - loss: 0.0553 - accuracy: 0.9757
# Epoch 4/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0488 - accuracy: 0.9788
# Epoch 5/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0460 - accuracy: 0.9799
# Epoch 6/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0450 - accuracy: 0.9804
# Epoch 7/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0442 - accuracy: 0.9808
# Epoch 8/100
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0435 - accuracy: 0.9811
# Epoch 9/100
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0429 - accuracy: 0.9814
# Epoch 10/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0425 - accuracy: 0.9817
# Epoch 11/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0424 - accuracy: 0.9816
# Epoch 12/100
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0428 - accuracy: 0.9813
# Epoch 13/100
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0424 - accuracy: 0.9816
# Epoch 14/100
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0422 - accuracy: 0.9817
# Epoch 15/100
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0420 - accuracy: 0.9818
# Epoch 16/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0420 - accuracy: 0.9817
# Epoch 17/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0420 - accuracy: 0.9817
# Epoch 18/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0415 - accuracy: 0.9820
# Epoch 19/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0412 - accuracy: 0.9821
# Epoch 20/100
# 7/7 [==============================] - 1s 17ms/step - loss: 0.0410 - accuracy: 0.9822
# Epoch 21/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0411 - accuracy: 0.9821
# Epoch 22/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0409 - accuracy: 0.9823
# Epoch 23/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0412 - accuracy: 0.9820
# Epoch 24/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0407 - accuracy: 0.9823
# Epoch 25/100
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0409 - accuracy: 0.9822
# Epoch 26/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0413 - accuracy: 0.9820
# Epoch 27/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0408 - accuracy: 0.9822
# Epoch 28/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0409 - accuracy: 0.9822
# Epoch 29/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0413 - accuracy: 0.9820
# Epoch 30/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0411 - accuracy: 0.9821
# Epoch 31/100
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0430 - accuracy: 0.9812
# Epoch 32/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0419 - accuracy: 0.9816
# Epoch 33/100
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0421 - accuracy: 0.9816
# Epoch 34/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0413 - accuracy: 0.9820
# Epoch 35/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0405 - accuracy: 0.9824
# Epoch 36/100
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0404 - accuracy: 0.9824
# Epoch 37/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0402 - accuracy: 0.9825
# Epoch 38/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0400 - accuracy: 0.9825
# Epoch 39/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0401 - accuracy: 0.9826
# Epoch 40/100
# 7/7 [==============================] - 1s 16ms/step - loss: 0.0398 - accuracy: 0.9827
# Epoch 41/100
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0404 - accuracy: 0.9824
# Epoch 42/100
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0414 - accuracy: 0.9818
# Epoch 43/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0409 - accuracy: 0.9822
# Epoch 44/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0398 - accuracy: 0.9826
# Epoch 45/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0403 - accuracy: 0.9823
# Epoch 46/100
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0413 - accuracy: 0.9819
# Epoch 47/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0409 - accuracy: 0.9821
# Epoch 48/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0408 - accuracy: 0.9822
# Epoch 49/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0412 - accuracy: 0.9819
# Epoch 50/100
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0409 - accuracy: 0.9821
# Epoch 51/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0405 - accuracy: 0.9823
# Epoch 52/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0414 - accuracy: 0.9819
# Epoch 53/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0412 - accuracy: 0.9818
# Epoch 54/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0404 - accuracy: 0.9823
# Epoch 55/100
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0405 - accuracy: 0.9823
# Epoch 56/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0397 - accuracy: 0.9827
# Epoch 57/100
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0395 - accuracy: 0.9827
# Epoch 58/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0397 - accuracy: 0.9827
# Epoch 59/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0398 - accuracy: 0.9826
# Epoch 60/100
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0404 - accuracy: 0.9823
# Epoch 61/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0414 - accuracy: 0.9818
# Epoch 62/100
# 7/7 [==============================] - 0s 19ms/step - loss: 0.0402 - accuracy: 0.9825
# Epoch 63/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0390 - accuracy: 0.9830
# Epoch 64/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0397 - accuracy: 0.9826
# Epoch 65/100
# 7/7 [==============================] - 1s 17ms/step - loss: 0.0398 - accuracy: 0.9826
# Epoch 66/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0412 - accuracy: 0.9818
# Epoch 67/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0399 - accuracy: 0.9825
# Epoch 68/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0389 - accuracy: 0.9829
# Epoch 69/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0386 - accuracy: 0.9831
# Epoch 70/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0386 - accuracy: 0.9832
# Epoch 71/100
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0385 - accuracy: 0.9832
# Epoch 72/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0384 - accuracy: 0.9832
# Epoch 73/100
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0383 - accuracy: 0.9833
# Epoch 74/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0382 - accuracy: 0.9833
# Epoch 75/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0381 - accuracy: 0.9833
# Epoch 76/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0382 - accuracy: 0.9833
# Epoch 77/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0387 - accuracy: 0.9830
# Epoch 78/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0384 - accuracy: 0.9832
# Epoch 79/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0383 - accuracy: 0.9833
# Epoch 80/100
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0384 - accuracy: 0.9832
# Epoch 81/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0379 - accuracy: 0.9834
# Epoch 82/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0384 - accuracy: 0.9832
# Epoch 83/100
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0379 - accuracy: 0.9834
# Epoch 84/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0378 - accuracy: 0.9835
# Epoch 85/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0386 - accuracy: 0.9830
# Epoch 86/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0397 - accuracy: 0.9825
# Epoch 87/100
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0382 - accuracy: 0.9833
# Epoch 88/100
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0381 - accuracy: 0.9833
# Epoch 89/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0383 - accuracy: 0.9832
# Epoch 90/100
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0390 - accuracy: 0.9828
# Epoch 91/100
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0404 - accuracy: 0.9822
# Epoch 92/100
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0384 - accuracy: 0.9831
# Epoch 93/100
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0372 - accuracy: 0.9837
# Epoch 94/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0380 - accuracy: 0.9833
# Epoch 95/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0372 - accuracy: 0.9837
# Epoch 96/100
# 7/7 [==============================] - 1s 16ms/step - loss: 0.0371 - accuracy: 0.9838
# Epoch 97/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0383 - accuracy: 0.9832
# Epoch 98/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0381 - accuracy: 0.9833
# Epoch 99/100
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0392 - accuracy: 0.9828
# Epoch 100/100
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0380 - accuracy: 0.9833

# %%
thresh = 0.5 #Experiment with changing this!
preds = unet(imgs_test).numpy()
preds = preds >= thresh

def show_preds_helper(imgs_test, masks_test, preds, ind):
    show_lung_mask_pred_sbs(imgs_test[ind], masks_test[ind], preds[ind])
    plt.show()

interact(lambda i: show_preds_helper(imgs_test, masks_test, preds, i), i=(0, len(preds)-1));
# Out:
# interactive(children=(IntSlider(value=26, description='i', max=53), Output()), _dom_classes=('widget-interact'…

# %% [markdown]
# ## References and Acknowledgements:
# * Some of these exercises were inspired by CS271 at Stanford
# * [Data](https://www.kaggle.com/kmader/finding-lungs-in-ct-data/data?select=lung_stats.csv)
# * [Dice Loss](https://lars76.github.io/neural-networks/object-detection/losses-for-segmentation/)
# * [Tensorflow](https://www.tensorflow.org/api_docs/python/tf/keras)
#
# Original Notebook by Harry Sha
